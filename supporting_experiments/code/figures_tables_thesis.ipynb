# %% [markdown]
# # Scripts for floats
# This file contains short scripts that were written for the sole purpose of generating tables and / or figures for the thesis

# %%
#imports
import pandas as pd
import numpy as np

# %% [markdown]
# ### Overview on media composition

# %%
media = pd.read_csv('/Users/baeuerle/Organisation/Masterarbeit/refinegems/data/media_db.csv', sep=';').drop('name', axis=1)
lb = media.drop('description', axis=1)[media.drop('description', axis=1)['medium']=='LB'].drop('medium', axis=1).rename({'BiGG':'LB'}, axis=1)

media = pd.read_csv('/Users/baeuerle/Organisation/Masterarbeit/refinegems/data/media_db.csv', sep=';').drop('name', axis=1)
m9 = media.drop('description', axis=1)[media.drop('description', axis=1)['medium']=='M9'].drop('medium', axis=1).rename({'BiGG':'M9'}, axis=1)

media = pd.read_csv('/Users/baeuerle/Organisation/Masterarbeit/refinegems/data/media_db.csv', sep=';').drop('name', axis=1)
rpmi = media.drop('description', axis=1)[media.drop('description', axis=1)['medium']=='RPMI'].drop('medium', axis=1).rename({'BiGG':'RPMI'}, axis=1)

media = pd.read_csv('/Users/baeuerle/Organisation/Masterarbeit/refinegems/data/media_db.csv', sep=';').drop('name', axis=1)
snm = media.drop('description', axis=1)[media.drop('description', axis=1)['medium']=='SNM3'].drop('medium', axis=1).rename({'BiGG':'SNM'}, axis=1)

media = pd.read_csv('/Users/baeuerle/Organisation/Masterarbeit/refinegems/data/media_db.csv', sep=';').drop('name', axis=1)
cgx = media.drop('description', axis=1)[media.drop('description', axis=1)['medium']=='CGXlab'].drop('medium', axis=1).rename({'BiGG':'CGXII'}, axis=1)

all = lb.reset_index().drop('index', 
                    axis=1).join(rpmi.reset_index().drop('index', 
                    axis=1), how='outer').join(snm.reset_index().drop('index', 
                    axis=1), how='outer').join(m9.reset_index().drop('index', 
                    axis=1), how='outer').join(cgx.reset_index().drop('index', 
                    axis=1), how='outer').replace({np.NaN: ' '})#.to_csv(index=False)
all.to_clipboard()#.to_latex(index=False)

# %%
dfs = np.split(all,len(all.columns), axis=1)
dfs = [df.set_index(df.columns[0], drop=False) for df in dfs]
dfs[0].join(dfs[1:]).reset_index(drop=True).notnull().astype("int").fillna(0).to_clipboard() #

# %%
table = pd.read_excel('/Users/baeuerle/Organisation/Masterarbeit/Nextcloud/master_thesis/paper/results.xlsx', sheet_name='composition')
table = table[['BiGG', 'CGXII']].dropna()
list_mets = table[table['CGXII'] != 0.0]['BiGG'].to_list()
set(cgx['CGXlab'].to_list()) -set(list_mets)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/s0/m197rw591kxcl13y56pqhf9m0000gs/T/ipykernel_35832/1708279527.py in <module>
# ----> 1 table = pd.read_excel('/Users/baeuerle/Organisation/Masterarbeit/Nextcloud/master_thesis/paper/results.xlsx', sheet_name='composition')
#       2 table = table[['BiGG', 'CGXII']].dropna()
#       3 list_mets = table[table['CGXII'] != 0.0]['BiGG'].to_list()
#       4 set(cgx['CGXlab'].to_list()) -set(list_mets)
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     297                 )
#     298                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 299             return func(*args, **kwargs)
#     300
#     301         return wrapper
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     334     if not isinstance(io, ExcelFile):
#     335         should_close = True
# --> 336         io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     337     elif engine and engine != io.engine:
#     338         raise ValueError(
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas/io/excel/_base.py in __init__(self, path_or_buffer, engine, storage_options)
#    1069                 ext = "xls"
#    1070             else:
# -> 1071                 ext = inspect_excel_format(
#    1072                     content=path_or_buffer, storage_options=storage_options
#    1073                 )
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas/io/excel/_base.py in inspect_excel_format(path, content, storage_options)
#     947     assert content_or_path is not None
#     948
# --> 949     with get_handle(
#     950         content_or_path, "rb", storage_options=storage_options, is_text=False
#     951     ) as handle:
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     649         else:
#     650             # Binary mode
# --> 651             handle = open(handle, ioargs.mode)
#     652         handles.append(handle)
#     653
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/baeuerle/Organisation/Masterarbeit/Nextcloud/master_thesis/paper/results.xlsx'

# %%
table = pd.read_excel('/Users/baeuerle/Organisation/Masterarbeit/Nextcloud/master_thesis/paper/results.xlsx', sheet_name='composition')
bigg_list = table['BiGG'].to_list()
bigg_metabs = pd.read_csv('bigg_models_metabolites.txt', sep='\t')
bigg_metabs
# Out:
#                                                  bigg_id  \
# 0                                             12dgr120_c
# 1                                             12dgr140_c
# 2                                             12dgr180_c
# 3                                             14glucan_c
# 4                                                15dap_c
# ...                                                  ...
# 15719  udcdpglcnac_a1_3_galnac_a1_4_glc_b1_6_fuc3nac_...
# 15720  udcdpgalnac_b1_3_glc_b1_2_glcnac_b1_4_gal_b1_4...
# 15721                                         LPS51_VL_e
# 15722                                            LPS54_p
# 15723                                         LPS60__L_p
#
#                                        universal_bigg_id  \
# 0                                               12dgr120
# 1                                               12dgr140
# 2                                               12dgr180
# 3                                               14glucan
# 4                                                  15dap
# ...                                                  ...
# 15719  udcdpglcnac_a1_3_galnac_a1_4_glc_b1_6_fuc3nac_...
# 15720  udcdpgalnac_b1_3_glc_b1_2_glcnac_b1_4_gal_b1_4...
# 15721                                           LPS51_VL
# 15722                                              LPS54
# 15723                                           LPS60__L
#
#                                                     name  \
# 0         1,2-Diacyl-sn-glycerol (didodecanoyl, n-C12:0)
# 1      1,2-Diacyl-sn-glycerol (ditetradecanoyl, n-C14:0)
# 2       1,2-Diacyl-sn-glycerol (dioctadecanoyl, n-C18:0)
# 3                                     1,4-alpha-D-glucan
# 4                                     1,5-Diaminopentane
# ...                                                  ...
# 15719  Cytoplasmic O antigen group O:55  repeat unit ...
# 15720  Periplasmic O antigen group O:38 repeat unit o...
# 15721  Periplasmic lipopolysaccharide group O:51 with...
# 15722  Extracellular lipopolysaccharide group O:54 wi...
# 15723  Extracellular lipopolysaccharide group O:60 wi...
#
#                                               model_list  \
# 0      iEC1364_W; iEC1349_Crooks; iEC1356_Bl21DE3; iM...
# 1      iECNA114_1301; iECSE_1348; iECO111_1330; iECOK...
# 2      iECB_1328; iECDH10B_1368; iEcE24377_1341; iECD...
# 3      iSFxv_1172; iUTI89_1310; iSSON_1240; iSbBS512_...
# 4      iECUMN_1333; iLF82_1304; iETEC_1333; iECSF_132...
# ...                                                  ...
# 15719                                            iYS1720
# 15720                                            iYS1720
# 15721                                            iYS1720
# 15722                                            iYS1720
# 15723                                            iYS1720
#
#                                           database_links  \
# 0      MetaNetX (MNX) Chemical: http://identifiers.or...
# 1      MetaNetX (MNX) Chemical: http://identifiers.or...
# 2      MetaNetX (MNX) Chemical: http://identifiers.or...
# 3      BioCyc: http://identifiers.org/biocyc/META:1-4...
# 4      KEGG Compound: http://identifiers.org/kegg.com...
# ...                                                  ...
# 15719                                                NaN
# 15720                                                NaN
# 15721                                                NaN
# 15722                                                NaN
# 15723                                                NaN
#
#                                             old_bigg_ids
# 0         12dgr120; 12dgr120[c]; 12dgr120_c; _12dgr120_c
# 1         12dgr140; 12dgr140[c]; 12dgr140_c; _12dgr140_c
# 2         12dgr180; 12dgr180[c]; 12dgr180_c; _12dgr180_c
# 3                                   14glucan; 14glucan_c
# 4                               15dap; 15dap[c]; 15dap_c
# ...                                                  ...
# 15719  udcdpglcnac(a1-3)galnac(a1-4)glc(b1-6)fuc3nac(...
# 15720  udcdpgalnac(b1-3)glc(((b1-2)glcnac)b1-4)gal(b1...
# 15721                               LPS51_VL; LPS51_VL_e
# 15722                                     LPS54; LPS54_p
# 15723                                LPS60_L_p; LPS60__L
#
# [15724 rows x 6 columns]

# %%
bigg_metabs[bigg_metabs['universal_bigg_id'].isin(bigg_list)][['universal_bigg_id','name']].set_index('universal_bigg_id').drop_duplicates().reindex(bigg_list).dropna().to_clipboard()
